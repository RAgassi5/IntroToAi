# %% [markdown]
# <a href="https://colab.research.google.com/github/RAgassi5/IntroToAi/blob/main/AgenticAI_Planning_Prolem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Agentic AI

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Install a Local LLM with Ollama
#
# To run this project locally, we will install and use **Ollama**, a lightweight runtime for local large language models.
#
# **Download Ollama:**
# https://ollama.com/
#
# Once installed, you can pull any model you want to run.
# Below are a few recommended examples, but you are free to pick any size or model from the Ollama library.
#
# ollama pull qwen3:0.6b
#
# or
#
# ollama pull ibm/granite4:350m
#
# or
#
# Choose any model you prefer, make sure the model supports tools.
# Browse available models here:
# https://ollama.com/library

# %% [markdown]
# ### Python requirements

# %%
# !pip install langgraph langchain-google-genai langchain-core mcp langchain-ollama
# Out:
# Requirement already satisfied: langgraph in /opt/anaconda3/lib/python3.12/site-packages (1.0.6)
# Requirement already satisfied: langchain-google-genai in /opt/anaconda3/lib/python3.12/site-packages (4.1.3)
# Requirement already satisfied: langchain-core in /opt/anaconda3/lib/python3.12/site-packages (1.2.7)
# Requirement already satisfied: mcp in /opt/anaconda3/lib/python3.12/site-packages (1.25.0)
# Requirement already satisfied: langchain-ollama in /opt/anaconda3/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-google-genai) (1.57.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (0.13.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.46.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth[requests]<3.0.0,>=2.46.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.47.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.32.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.46.0->google-auth[requests]<3.0.0,>=2.46.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.46.0->google-auth[requests]<3.0.0,>=2.46.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.2.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.46.0->google-auth[requests]<3.0.0,>=2.46.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.8)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (3.1.2)
# Requirement already satisfied: starlette>=0.27 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (0.51.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp) (0.40.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (0.30.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp) (0.21.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.21)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp) (8.1.7)

# %%
# !pip install unified-planning[pyperplan]
# Out:
# Requirement already satisfied: unified-planning[pyperplan] in /opt/anaconda3/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: pyparsing in /opt/anaconda3/lib/python3.12/site-packages (from unified-planning[pyperplan]) (3.0.9)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from unified-planning[pyperplan]) (3.2.1)
# Requirement already satisfied: ConfigSpace in /opt/anaconda3/lib/python3.12/site-packages (from unified-planning[pyperplan]) (1.2.1)
# Requirement already satisfied: up-pyperplan~=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from unified-planning[pyperplan]) (1.1.0)
# Requirement already satisfied: pyperplan==2.1 in /opt/anaconda3/lib/python3.12/site-packages (from up-pyperplan~=1.1.0->unified-planning[pyperplan]) (2.1)
# Requirement already satisfied: wheel in /opt/anaconda3/lib/python3.12/site-packages (from pyperplan==2.1->up-pyperplan~=1.1.0->unified-planning[pyperplan]) (0.43.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from ConfigSpace->unified-planning[pyperplan]) (2.2.6)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from ConfigSpace->unified-planning[pyperplan]) (1.17.0)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/lib/python3.12/site-packages (from ConfigSpace->unified-planning[pyperplan]) (4.15.0)
# Requirement already satisfied: more_itertools in /opt/anaconda3/lib/python3.12/site-packages (from ConfigSpace->unified-planning[pyperplan]) (10.1.0)

# %%
import os
print("Current working directory:", os.getcwd())
print("Files found:", os.listdir())
# You should see your .pddl files in this list
# Out:
# Current working directory: /Users/roiiagassi/Documents/BGU/Year 3.1/Intro to AI/AgenticAI
# Files found: ['assignment_4_project_agentic.pdf', 'AgenticAI_Planning_Prolem1.ipynb', '.DS_Store', 'community_garden.pddl', 'community_garden_problem_v1.pddl', 'AgenticAI_Planning_Problem5.ipynb', 'community_garden_problem_v4.pddl', 'community_garden_problem_v5.pddl', 'community_garden_problem_v2.pddl', 'IntroToAI3_CopyForAI4', 'uni_planner.py', 'community_garden_problem_v3.pddl', '.idea']

# %% [markdown]
# ## 1. Define FastMCP Tools

# %%
from mcp.server.fastmcp import FastMCP
import math
from unified_planning import Environment
from unified_planning.io import PDDLReader
from unified_planning.shortcuts import OneshotPlanner

# Initialize FastMCP
mcp = FastMCP("Unified Solver")

@mcp.tool()
def solve_planning_problem() -> str:
    """
    Runs the deterministic PDDL planner code to solve the Community Garden problem.
    """
    try:
        env = Environment()
        reader = PDDLReader(env)

        # UPDATE THESE FILENAMES to match exactly what you uploaded
        problem = reader.parse_problem("./community_garden.pddl", "./community_garden_problem_v1.pddl")

        with OneshotPlanner(name="pyperplan") as planner:
            result = planner.solve(problem)

        if result.plan is not None:
            output = "Plan found:\n"
            for action_instance in result.plan.actions:
                output += str(action_instance) + "\n"
            return output
        else:
            return "No plan found."
    except Exception as e:
        return f"Error running planner: {str(e)}"

# TO DO: Add more tools as needed for your application

# %% [markdown]
# ## 2. LLM + MCP

# %% [markdown]
# ### 2.1. Global instance of our LLM

# %%
import os
from langchain_ollama import ChatOllama
from langchain_google_genai import ChatGoogleGenerativeAI


# Choose your model here, can be Ollama or Google Gemini
# Can also switch between different model sizes as needed
#model = "qwen3:0.6b"
#model = "ibm/granite4:350m"
model = "qwen2.5:3b"
global_llm = ChatOllama(model=model, temperature=0.0)

# SETUP API KEY if using Google Gemini
#os.environ["GOOGLE_API_KEY"] = "YOUR_GOOGLE_API_KEY_HERE"

# model = "gemini-2.5-flash"
# model = "gemini-2.5-flash-lite"
# global_llm = ChatGoogleGenerativeAI(model=model, temperature=0)

# %% [markdown]
# ### 2.2. Our agent graph

# %%
from langgraph.graph import MessagesState, START, StateGraph
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import MemorySaver # Optional: For saving graph state


def create_agent_graph(sys_msg, tools):
    """ Creates a LangGraph StateGraph with the given tools integrated."""

    llm = global_llm

    if tools:
        llm_with_tools = llm.bind_tools(tools)
    else:
        llm_with_tools = llm

    # Node
    def assistant(state: MessagesState):
        return {
            "messages": [
                llm_with_tools.invoke([sys_msg] + state["messages"], think=False)
            ]
        }

    # Graph
    builder = StateGraph(MessagesState)

    # Define the basic graph structure
    builder.add_node("assistant", assistant)
    builder.add_edge(START, "assistant")

    if tools:
        builder.add_node("tools", ToolNode(tools))
        builder.add_conditional_edges(
            "assistant",
            tools_condition,
        )
        builder.add_edge("tools", "assistant")

    react_graph = builder.compile()

    return react_graph


async def run_agent(prompt, tools, sys_msg=""):

    sys_msg = SystemMessage(content=sys_msg)

    # 3. Create Graph
    graph = create_agent_graph(sys_msg, tools)

    # 4. Run (using ainvoke for async tools)
    config = {"configurable": {"thread_id": "1"}}
    result = await graph.ainvoke({"messages": [HumanMessage(content=prompt)]}, config)

    last_msg = result["messages"][-1].content

    # Extract tool names and outputs
    tools_used = []
    tools_output = []

    # Parsing logic specific to your request
    for msg in result["messages"]:
        # In LangChain, tool calls are usually in 'tool_calls' attribute of AIMessage
        # or 'name' attribute if it is a ToolMessage
        if hasattr(msg, 'tool_calls') and msg.tool_calls:
             for tool_call in msg.tool_calls:
                tools_used.append(tool_call['name'])

        if msg.type == 'tool':
            tools_output.append(msg.content)

    return last_msg, tools_used, tools_output

# %% [markdown]
# ### 2.3. Tools that run spacific agent (with tools and without)

# %%
@mcp.tool()
async def ask_agent_with_tools(prompt) -> str:
    """ Runs the agent that has access to the deterministic PDDL planner tool."""
    # This agent has access to the 'solve_planning_problem' tool defined above
    tools = [solve_planning_problem]
    results = await run_agent(prompt, tools)
    return results[0]

try:
    with open("community_garden.pddl", "r") as f:
        domain_text = f.read()
    with open("community_garden_problem_v1.pddl", "r") as f:
        problem_text = f.read()
except FileNotFoundError:
    print("Error: Please make sure the .pddl files are in the notebook directory.")
    domain_text = "Domain file not found."
    problem_text = "Problem file not found."

@mcp.tool()
async def ask_agent_without_tools(prompt) -> str:
    """ Runs the agent WITHOUT tools. It must try to solve the problem using only the PDDL description."""

    # We inject the text we just read into the prompt
    pddl_context = f"""
    You are a planning algorithm.
    Here is the PDDL Domain:
    {domain_text}

    Here is the PDDL Problem:
    {problem_text}

    Based ONLY on this text, generate a valid plan to reach the goal.
    List the actions step-by-step.
    """

    full_prompt = f"{pddl_context}\n\nUser Request: {prompt}"

    results = await run_agent(full_prompt, [])
    return results[0]

# %% [markdown]
# ## 3. Run the Test

# %%
# THE JUDGE AGENT RUNNER

sys_msg = """
    You are a Research Supervisor for an AI Planning course. You have two assistants:
    1. 'ask_agent_with_tools': runs a verified PDDL planner algorithm (Ground Truth).
    2. 'ask_agent_without_tools': is an LLM attempting to solve the problem intuitively.

    Your Goal:
    1. Call 'ask_agent_with_tools' to get the mathematically correct plan for the Community Garden problem.
    2. Call 'ask_agent_without_tools' to see how the LLM attempts to solve it.
    3. Compare the two plans. Did the LLM hallucinate impossible actions? Did it miss preconditions?
    4. Provide a final summary explaining the differences.
    """

prompt = "I need a through comparison report for the planning problem. Run both agents and compare their plans."

tool_list = [ask_agent_with_tools, ask_agent_without_tools]

response, tools, outputs = await run_agent(prompt, tool_list, sys_msg)
print(f"Response: {response}")
print(f"Tools Used: {tools}")
print(f"Tool Outputs: {outputs}")
# Out:
# [01/18/26 10:50:28] INFO     HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"   ]8;id=41736;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=395502;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py#1025\1025]8;;\
# [01/18/26 10:52:18] INFO     HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"   ]8;id=692754;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=674856;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py#1025\1025]8;;\
# NOTE: To disable printing of planning engine credits, add this line to your code: `up.shortcuts.get_environment().credits_stream = None`
#   *** Credits ***
#   * In operation mode `OneshotPlanner` at line 22 of `/var/folders/9t/qq0sfdr93rj8j4thhgljn77c0000gq/T/ipykernel_16466/470738424.py`, you are using the following planning engine:
#   * Engine name: pyperplan
#   * Developers:  Albert-Ludwigs-Universität Freiburg (Yusra Alkhazraji, Matthias Frorath, Markus Grützner, Malte Helmert, Thomas Liebetraut, Robert Mattmüller, Manuela Ortlieb, Jendrik Seipp, Tobias Springenberg, Philip Stahl, Jan Wülfing)
#   * Description: Pyperplan is a lightweight STRIPS planner written in Python.
# [01/18/26 10:52:49] INFO     Grounding start: instance_7                                             ]8;id=18220;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=30480;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#128\128]8;;\
#                     INFO     Relevance analysis removed 0 facts                                    ]8;id=690791;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/grounding.py\grounding.py]8;;\:]8;id=485922;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/grounding.py#160\160]8;;\
#                     INFO     Grounding end: instance_7                                               ]8;id=416183;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=798179;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#132\132]8;;\
#                     INFO     307 Variables created                                                   ]8;id=210514;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=261781;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#133\133]8;;\
#                     INFO     7504 Operators created                                                  ]8;id=211245;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=520601;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#134\134]8;;\
# [01/18/26 10:52:50] INFO     Search start: instance_7                                                ]8;id=141339;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=306585;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#139\139]8;;\
#                     INFO     Initial h value: 28.000000                                               ]8;id=722662;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py\a_star.py]8;;\:]8;id=662560;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py#136\136]8;;\
# [01/18/26 10:54:12] INFO     HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"   ]8;id=224570;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=503153;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py#1025\1025]8;;\
# [01/18/26 10:55:00] INFO     Goal reached. Start extraction of solution.                              ]8;id=51137;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py\a_star.py]8;;\:]8;id=953460;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py#156\156]8;;\
#                     INFO     66 Nodes expanded                                                        ]8;id=192626;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py\a_star.py]8;;\:]8;id=332227;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/search/a_star.py#157\157]8;;\
#                     INFO     Search end: instance_7                                                  ]8;id=855786;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py\planner.py]8;;\:]8;id=407786;file:///opt/anaconda3/lib/python3.12/site-packages/pyperplan/planner.py#147\147]8;;\
# [01/18/26 10:55:46] INFO     HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"   ]8;id=538581;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=634415;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py#1025\1025]8;;\
# [01/18/26 10:58:10] INFO     HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"   ]8;id=972577;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=777423;file:///opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py#1025\1025]8;;\
# Response: Based on the plans provided by both agents, here is a comparison:
#
# ### Agent with Tools (ask_agent_with_tools)
# - **Sequence of Actions:**
#   1. Move volunteer1 to cell33, then move them to gardenplot.
#   2. Move volunteer2 to cell12, then move them to gardenplot.
#   3. Move volunteer3 to cell13, then move them to cell35 and finally to gardenplot.
#   4. Get a watering can for volunteer3 at cell35 and bring it to the gardenplot.
#   5. Move volunteer3 from cell35 to gardenplot.
#   6. Move volunteer1 to gardenplot in cell30.
#   7. Get a tiller for volunteer1 in cell30, then move them there.
#   8. Move volunteer1 from cell30 to gardenplot.
#   9. Till the soil using the tiller at gardenplot.
#   10. Move volunteer2 to gardenplot in cell38.
#   11. Get seeds for volunteer2 in cell38 and bring them to gardenplot.
#   12. Move volunteer2 from cell38 to gardenplot.
#   13. Sow the seeds in gardenplot.
#   14. Water the garden using the watering can at gardenplot.
#   15. Celebrate the opening of the garden with volunteers 1, 2, and 3.
#
# ### Agent Without Tools (ask_agent_without_tools)
# - **Sequence of Actions:**
#   1. Move volunteer1 to cell33, then move them to gardenPlot.
#   2. Move volunteer2 to cell12, then move them to gardenPlot.
#   3. Move volunteer3 to cell13, then move them to gardenPlot.
#   4. Get a tiller for volunteer1 in cell30 and bring it to gardenPlot.
#   5. Till the soil using the tiller at gardenPlot.
#   6. Get seeds for volunteer2 in cell38 and bring them to gardenPlot.
#   7. Sow the seeds in gardenPlot.
#   8. Get a watering can for volunteer3 at cell35, then move it to gardenPlot.
#   9. Water the garden using the wateringCan at gardenPlot.
#   10. Volunteer1 celebrates the garden opening.
#
# ### Comparison and Analysis
# - **Agent with Tools:** This plan is more detailed and specific about each step, including moving volunteers between different cells and ensuring they are in the correct locations before performing actions like getting tools or seeds. It also includes a celebratory action at the end.
#
# - **Agent Without Tools:** The agent without access to additional tools assumes that all necessary resources (tillers, watering cans) are already available in their respective places. This simplification might lead to missing some steps if these items need to be fetched or prepared first.
#
# ### Potential Issues
# 1. **Missing Precondition Checks:**
#    - Both plans assume the availability of tools and seeds without explicitly checking for them.
#
# 2. **Hallucinations:**
#    - The agent with tools provided a more detailed plan, but it might still contain some steps that are not logically necessary or could be simplified further.
#
# ### Summary
# The `ask_agent_with_tools` produced a comprehensive plan considering all the details and ensuring each step is correctly executed. However, both plans missed checking for the availability of essential resources like tillers and watering cans. The LLM's intuitive approach was simpler but might have overlooked these critical steps. It’s important to verify that all necessary conditions are met before executing actions.
#
# Would you like me to run any additional checks or provide more detailed analysis?
# Tools Used: ['ask_agent_with_tools', 'ask_agent_without_tools']
# Tool Outputs: ['The PDDL planner has generated a plan to transition the system from the initial state (all objects in the garage) to the goal state (vegetables and fruits are in their respective growing areas). Here is the sequence of actions:\n\n1. Move volunteer1 to cell33, then move them to gardenplot.\n2. Move volunteer2 to cell12, then move them to gardenplot.\n3. Move volunteer3 to cell13, then move them to cell35 and finally to gardenplot.\n4. Get a watering can for volunteer3 at cell35 and bring it to the gardenplot.\n5. Move volunteer3 from cell35 to gardenplot.\n6. Move volunteer1 to gardenplot in cell30.\n7. Get a tiller for volunteer1 in cell30, then move them there.\n8. Move volunteer1 from cell30 to gardenplot.\n9. Till the soil using the tiller at gardenplot.\n10. Move volunteer2 to gardenplot in cell38.\n11. Get seeds for volunteer2 in cell38 and bring them to gardenplot.\n12. Move volunteer2 from cell38 to gardenplot.\n13. Sow the seeds in gardenplot.\n14. Water the garden using the watering can at gardenplot.\n15. Celebrate the opening of the garden with volunteers 1, 2, and 3.\n\nThis plan assumes specific locations for each action but should be adaptable based on your actual layout of the community garden. Ensure that all necessary resources (like seeds, tools) are available in their respective places before starting the planting process.', "To reach the goal state of having all vegetables and fruits in their respective growing areas, we need to follow a sequence of actions based on the provided PDDL problem domain. Here is a step-by-step plan:\n\n1. **Move volunteer1 from cell33 to gardenPlot:**\n   - Effect: (at volunteer1 gardenPlot)\n\n2. **Move volunteer2 from cell12 to gardenPlot:**\n   - Effect: (at volunteer2 gardenPlot)\n\n3. **Move volunteer3 from cell13 to gardenPlot:**\n   - Effect: (at volunteer3 gardenPlot)\n\n4. **Get tiller from cell30 to gardenPlot:**\n   - Effect: (has-tiller volunteer1 tiller1)\n   - Effect: (not (at tiller1 cell30))\n\n5. **Till soil using the tiller in gardenPlot:**\n   - Effect: (soil-is-tilled)\n\n6. **Get seeds from cell38 to gardenPlot:**\n   - Effect: (has-seeds volunteer2 seeds1)\n   - Effect: (not (at seeds1 cell38))\n\n7. **Sow seeds using the seeds in gardenPlot:**\n   - Effect: (seeds-are-sown)\n\n8. **Get wateringCan from cell35 to gardenPlot:**\n   - Effect: (has-watering-can volunteer3 wateringCan1)\n   - Effect: (not (at wateringCan1 cell35))\n\n9. **Water the garden using the wateringCan in gardenPlot:**\n   - Effect: (garden-is-watered)\n\n10. **Volunteer1 celebrates the garden opening:**\n    - Effect: (garden-is-thriving)\n\nThis sequence of actions will lead to the goal state where all vegetables and fruits are in their respective growing areas, as specified by the problem domain's predicates."]
